# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install git+https://github.com/huggingface/diffusers
# !pip install omegaconf
# !pip install torch
# !pip install safetensors
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-gedp5viq
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-gedp5viq
#   Resolved https://github.com/huggingface/transformers to commit 0083b149e9d69a2f1dcd380b42902c3c3e75d7af
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 72.5 MB/s eta 0:00:00
# ...
#   Created wheel for transformers: filename=transformers-4.29.0.dev0-py3-none-any.whl size=6991784 sha256=e2c526e3798b76b498b09e75156e94510df4dbb6968200d31e2a81aab4291f82
# ...

# %%
# !git clone https://github.com/huggingface/diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 24899, done.
# remote: Counting objects: 100% (532/532), done.
# remote: Compressing objects: 100% (215/215), done.
# remote: Total 24899 (delta 327), reused 446 (delta 289), pack-reused 24367
# Receiving objects: 100% (24899/24899), 31.36 MiB | 17.53 MiB/s, done.
# Resolving deltas: 100% (17983/17983), done.

# %%
import diffusers
import omegaconf
import torch
from diffusers.pipelines.stable_diffusion.convert_from_ckpt import download_from_original_stable_diffusion_ckpt

# %%
pipe = download_from_original_stable_diffusion_ckpt(
    checkpoint_path='/content/drive/MyDrive/stable diffusion models/realisticVisionV20_v20.safetensors',
    from_safetensors=True,
    load_safety_checker=True)
# Out:
# global_step key not found in model
# ...

# %%
pipe.save_pretrained("/content/drive/MyDrive/ANLY521/sd15-models/realisticVisionV20_v20")

# %%
images = pipe('a cute girl')
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
images[0][0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F49183E82B0>

# %%
images[0][0].save('1.png')

# %% [markdown]
# ## Load Models

# %%
from diffusers import StableDiffusionControlNetPipeline, ControlNetModel, StableDiffusionPipeline
from diffusers import DiffusionPipeline
import torch

# %%
pipe = StableDiffusionPipeline.from_pretrained(
    '/content/drive/MyDrive/ANLY521/sd15-models/deliberate_v2', torch_dtype=torch.float16
)
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# /usr/local/lib/python3.9/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
